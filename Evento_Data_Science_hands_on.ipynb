# %% [markdown]
# <a href="https://colab.research.google.com/github/leocassiosilva/Analise-de-dados/blob/main/Evento_Data_Science_hands_on.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Request lib para https
import requests

# BS para scraping de HMTL
from bs4 import BeautifulSoup

# Lib para modelagem de dados
import pandas as pd

# %%
# Carregamento da Pagina

# Link do Site
Site = 'http://www.ssp.sp.gov.br/Estatistica/ViolenciaMulher.aspx'

# Carregando
Pagina = requests.get( Site )

# %%
# Coleanto as infos da pagina
Coleta = BeautifulSoup( Pagina.text, 'html.parser')

# %%
Coleta
# Out:
# <!DOCTYPE html>
#
# <html ng-app="modPortal" xmlns="http://www.w3.org/1999/xhtml">
# <head ng-controller="ctrlHead"><meta content="!" name="fragment"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <title>
# 	SSP
# </title>
# <!-- Bootstrap core CSS -->
# <link href="/Content/bootstrap.min.css" rel="stylesheet"/>
# <!-- Bootstrap theme -->
# <link href="/Content/bootstrap-theme.min.css" rel="stylesheet"/>
# <!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->
# <link href="/Content/ie10-viewport-bug-workaround.css" rel="stylesheet"/>
# <!-- Custom styles for this template -->
# <link href="/Content/theme.css" rel="stylesheet"/><link href="/Content/SearchForm.css" rel="stylesheet"/><link href="/Content/proxima.css" rel="stylesheet"/><link href="/Content/angular.css" rel="stylesheet"/><link href="/Content/slide.and.push.css" rel="stylesheet"/><link href="/Content/media.css" rel="stylesheet"/><link href="/Content/page.css" rel="stylesheet"/><link href="/Content/estat_new.css" rel="stylesheet"/><link href="/Content/font-awesome.min.css" rel="stylesheet"/>
# <!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->
# <script src="/Scripts/ie10-viewport-bug-workaround.js"></script>
# <!-- Just for debugging purposes. Don't actually copy these 2 lines! -->
# <!--[if lt IE 9]><script src="../../assets/js/ie8-responsive-file-warning.js"></script><![endif]-->
# <script src="/Scripts/ie-emulation-modes-warning.js"></script>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# 		  <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# 		  <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
# 		<![endif]-->
# <!--Style-->
# <!--Scripts-->
# <script src="/Scripts/jquery-3.1.1.min.js"></script>
# <script src="/Scripts/jquery.maskedinput.min.js"></script>
# <script src="/Scripts/angular.min.js"></script>
# <script src="/Scripts/angular-cookies.min.js"></script>
# <script src="/Scripts/bootstrap.min.js"></script>
# <script src="/Scripts/angular-ui/ui-bootstrap-tpls.min.js"></script>
# <script src="/Scripts/i18n/angular-locale_pt-br.js"></script>
# <script src="/Scripts/slide.and.push.js"></script>
# <script src="https://www.youtube.com/iframe_api"></script>
# <script src="/Scripts/angular-youtube-embed.js"></script>
# <script src="/Scripts/angular-seo-master/angular-seo.js"></script>
# <script src="/Scripts/angular-socialshare.min.js"></script>
# <!--AngularControllers e appMain-->
# <script src="/app/app.js"></script>
# <script src="/app/controllers/ctrlModal.js"></script>
# <script src="/app/controllers/ctrlPesquisa.js"></script>
# <script src="/app/controllers/ctrlHead.js"></script>
# <script type="text/javascript">
# 		//Coloca mascara para o campo
# 		//campo - id do campo
# 		//tipo_mascara - tipo da mascara a ser aplicada (cpf, data, ano, idade);
# 		function mascara(campo, tipo_mascara) {
# 			var mascara = "";
# 			switch (tipo_mascara) {
# 				case "cpf":
# 					mascara = "999.999.999-99";
# 					break;
# 				case "data":
# 					mascara = "99/99/9999";
# 					break;
# 				case "hora":
# 					mascara = "99:99";
# 					break;
# 				case "ano":
# 					mascara = "9999";
# 					break;
# 				case "cnpj":
# 					mascara = "99.999.999/9999-99";
# 					break;
# 				case "telefone":
# 					mascara = "(99)9999-9999";
# 					break;
# 				case "celular":
# 					mascara = "(99)99999999?9";
# 					break;
# 				case "cep":
# 					mascara = "99999-999";
# 					break;
# 			}
#
# 			$(campo).mask(mascara,
# 				{ placeholder: " " }
# 			);
# 		}
#
# 	</script>
# <style>
# 		body {
# 			padding-top: 0px !important;
# 			padding-right: 0px !important;
# 		}
#
# 		navbar-right { margin-right: 0 !important; }
#
# 		@media (max-width: 767px) {
# 			.img-thumbnail {
# 				display: inline-block !important;
# 				border: 0px !important;
# 				border-radius: 0px !important;
# 			}
# 		}
#
# 		.icone_menu {
# 			width: 12%;
# 			padding-right: 5px;
# 		}
#
# 		h4 {
# 			font-weight: bolder;
# 		}
#
# 		.row {
# 			margin-left: 0px !important;
# 			margin-right: 0px !important;
# 		}
#
# 		.faixatop, .faixa_escuro {
# 			background: #003399;
# 		}
#
# 		.noborder {
# 			border: 0;
# 			border-radius: 0px !important;
# 		}
#
# 		.navbar {
# 			position: relative;
# 			min-height: 50px;
# 			margin-bottom: 0px;
# 			border: 0px solid transparent !important;
# 		}
#
# 		.navbar-default {
# 			-webkit-box-shadow: inset 0 0 0 rgba(255,255,255,.15),0 1px 5px rgba(0,0,0,.075);
# 			box-shadow: inset 0 0 0 rgba(255,255,255,.15),0 1px 5px rgba(0,0,0,.075);
# 		}
#
# 		.header_text, .header_text2, .header_text3 {
# 			color: #FFFFFF !important;
# 			font-family: proxima;
# 		}
#
# 		.navMenu > li > a {
# 			background-color: #003399 !important;
# 			color: #fff !important;
# 			padding: 5px 20px;
# 		}
#
# 		.navbarMenu {
# 			min-height: 30px;
# 			max-height: 40px;
# 		}
#
# 		.espacovertical {
# 			margin-top: 15px;
# 		}
#
# 		.textoicones {
# 			font-family: proxima;
# 			color: #666;
# 			font-size: 12px;
# 			margin-left: 10px;
# 			margin-right: 10px;
# 		}
#
# 		.textorodape2 {
# 			font-family: proxima;
# 			color: #fff;
# 			font-size: 18px;
# 		}
#
# 		.container {
# 			padding-left: 0px !important;
# 			padding-right: 0px !important;
# 		}
#
# 		.hidden-sm .hidden-xs {
# 			padding-left: 0px !important;
# 		}
#
# 		.col-lg-1, .col-lg-10, .col-lg-11, .col-lg-12, .col-lg-2, .col-lg-3, .col-lg-4, .col-lg-5, .col-lg-6, .col-lg-7, .col-lg-8, .col-lg-9, .col-md-1, .col-md-10, .col-md-11, .col-md-12, .col-md-2, .col-md-3, .col-md-4, .col-md-5, .col-md-6, .col-md-7, .col-md-8, .col-md-9, .col-sm-1, .col-sm-10, .col-sm-11, .col-sm-12, .col-sm-2, .col-sm-3, .col-sm-4, .col-sm-5, .col-sm-6, .col-sm-7, .col-sm-8, .col-sm-9, .col-xs-1, .col-xs-10, .col-xs-11, .col-xs-12, .col-xs-2, .col-xs-3, .col-xs-4, .col-xs-5, .col-xs-6, .col-xs-7, .col-xs-8, .col-xs-9 {
# 			padding-left: 0px !important;
# 			padding-right: 0px !important;
# 		}
#
# 		.noPadding {
# 			padding-left: 0px !important;
# 			padding-right: 0px !important;
# 		}
#
# 		.img-center {
# 			margin: 0 auto;
# 		}
#
# 		.img-display {
# 			display: block !important;
# 		}
#
# 		.img-thumbnail {
# 			border: 0px !important;
# 			border-radius: 0px !important;
# 			padding: 0px !important;
# 		}
#
# 		.faixaazul, .faixaamarela, .faixavermelho {
# 			min-height: 3px;
# 			font-weight: bold;
# 			margin-bottom: 10px;
# 		}
#
# 		.faixaazul {
# 			background-color: #003399;
# 		}
#
# 		.faixaamarela {
# 			background-color: #edb01f;
# 		}
#
# 		.faixavermelho {
# 			background-color: #bb1c0b;
# 		}
#
# 		.period {
# 			padding-right: 15px;
# 			float: right;
# 		}
#
# 		.form-control {
# 			border-radius: 0px !important;
# 		}
#
# 		.btn {
# 			border-radius: 0px !important;
# 		}
#
# 		.alert {
# 			border-radius: 0px !important;
# 		}
#
# 		.modal-content {
# 			border-radius: 0px !important;
# 		}
#
# 		.panel-group .panel {
# 			border-radius: 0px !important;
# 		}
# 		.list-group {
# 		  border-radius: 0px !important;
# 		  padding: 0px !important;
# 		}
# 		.panel-heading {
# 			border-top-left-radius: 0px !important;
# 			border-top-right-radius: 0px !important;
# 		}
# 		p{
# 			font-size: 18px !important;
# 			text-align: justify !important;
# 		}
# 		h2{
# 			font-size: 20px !important;
# 			font-weight: bolder !important;
# 		}
# 		a.spmenu-button {
# 			font-size: 40px !important;
# 			width: 35px !important;
# 		}
# 		*{
# 			-webkit-overflow-scrolling: touch !important;
# 		}
#
# 	</style>
# <script src="../Scripts/selectbox_goto.js" type="text/javascript"></script>
# <script type="text/javascript">
#         $(document).ready(function () {
#             if ($(".exibeNota").val() == "0") {
#                 $(".fundo").hide();
#                 $(".pnlNota").hide();
#             }
#             $("#fechar_nota").click(function () {
#                 $(".fundo").hide();
#                 $(".pnlNota").hide();
#                 $(".exibeNota").val('0');
#             });
#         });
#     </script>
# <style type="text/css">
#         ul.nota li {
#             float: none !important;
#             font-size: 11px !important;
#         }
#     </style>
# </head>
# <body role="document" style="font-family: proxima;">
# <div class="container hidden-xs hidden-sm hidden-md">
# <div class="row header-top">
# <nav class="external-links">
# <ul class="menusocial">
# <li class="item"><a href="http://www.saopaulo.sp.gov.br/" target="_blank">Portal do Governo</a></li>
# <li class="item"><a href="http://www.policiamilitar.sp.gov.br/" target="_blank">Polícia Militar</a></li>
# <li class="item"><a href="http://www.policiacivil.sp.gov.br/" target="_blank">Polícia Civil</a></li>
# <li class="item"><a href="http://www.policiacientifica.sp.gov.br/" target="_blank">Polícia Científica</a></li>
# <li class="item dropdown">
# <a aria-expanded="False" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" id="dropdownMenu1" type="button">
#                             Destaques
#                             <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a class="" href="http://www.saopaulo.sp.gov.br/sis/noticias.asp">SP Notícias</a>
# </li>
# <li>
# <a class="" href="http://www.poupatempo.sp.gov.br/">Poupatempo</a>
# </li>
# <li>
# <a class="" href="http://www.acessasaopaulo.sp.gov.br/">Acessa São Paulo</a>
# </li>
# <li>
# <a class="" href="http://www.e-negociospublicos.com.br/">Licitações</a>
# </li>
# <li class="divider" role="separator"></li>
# <li class="dropdown-header">
# 						Secretarias:<li></li>
# <li>
# <a class="" href="http://www.sap.sp.gov.br/">- Administração Penitenciária</a>
# </li>
# <li>
# <a class="" href="http://www.agricultura.sp.gov.br/">- Agricultura e Abastecimento</a>
# </li>
# <li>
# <a class="" href="http://www.desenvolvimentosocial.sp.gov.br/">- Assistência e Desenvolvimento Social</a>
# </li>
# <li>
# <a class="" href="http://www.casacivil.sp.gov.br/">- Casa Civil</a>
# </li>
# <li>
# <a class="" href="http://www.casamilitar.sp.gov.br/">- Casa Militar</a>
# </li>
# <li>
# <a class="" href="http://www.comunicacao.sp.gov.br/">- Comunicação</a>
# </li>
# <li>
# <a class="" href="http://www.cultura.sp.gov.br/">- Cultura</a>
# </li>
# <li>
# <a class="" href="http://www.desenvolvimento.sp.gov.br/">- Desenvolvimento</a>
# </li>
# <li>
# <a class="" href="http://www.pessoacomdeficiencia.sp.gov.br/">- Direitos da Pessoa com Deficiência</a>
# </li>
# <li>
# <a class="" href="http://www.planejamento.sp.gov.br/">- Economia e Planejamento</a>
# </li>
# <li>
# <a class="" href="http://www.educacao.sp.gov.br/">- Educação</a>
# </li>
# <li>
# <a class="" href="http://www.emprego.sp.gov.br/">- Emprego e Relações do Trabalho</a>
# </li>
# <li>
# <a class="" href="http://www.ensinosuperior.sp.gov.br/">- Ensino Superior</a>
# </li>
# <li>
# <a class="" href="http://www.sejel.sp.gov.br/">- Esporte, Lazer e Turismo</a>
# </li>
# <li>
# <a class="" href="http://www.fazenda.sp.gov.br/">- Fazenda</a>
# </li>
# <li>
# <a class="" href="http://www.gestaopublica.sp.gov.br/">- Gestão Pública</a>
# </li>
# <li>
# <a class="" href="http://www.habitacao.sp.gov.br/">- Habitação</a>
# </li>
# <li>
# <a class="" href="http://www.justica.sp.gov.br/">- Justiça e Defesa da Cidadania</a>
# </li>
# <li>
# <a class="" href="http://www.ambiente.sp.gov.br/">- Meio Ambiente</a>
# </li>
# <li>
# <a class="" href="http://www.pge.sp.gov.br/">- Procuradoria Geral do Estado</a>
# </li>
# <li>
# <a class="" href="http://www.relacoesinstitucionais.sp.gov.br/">- Relações Institucionais</a>
# </li>
# <li>
# <a class="" href="http://www.energia.sp.gov.br/">- Saneamento e Energia</a>
# </li>
# <li>
# <a class="" href="http://www.saude.sp.gov.br/">- Saúde</a>
# </li>
# <li>
# <a class="" href="http://www.ssp.sp.gov.br/">- Segurança Pública</a>
# </li>
# <li>
# <a class="" href="http://www.transportes.sp.gov.br/">- Transportes</a>
# </li>
# <li>
# <a class="" href="http://www.stm.sp.gov.br/">- Transportes Metropolitanos</a>
# </li>
# </li>
# </ul>
# </li>
# </ul>
# </nav>
# <div class="aside">
# <nav class="social-media">
# <ul class="menusocial">
# <li class="item"><a href="https://www.facebook.com/segurancapublicasp" target="_blank"><i class="ico-header-facebook">facebook</i></a></li>
# <li class="item"><a href="https://twitter.com/SegurancaSP" target="_blank"><i class="ico-header-twitter">twitter</i></a></li>
# </ul>
# </nav>
# </div>
# </div>
# <!--Cabeçalho
#   <nav class="navbar navbar-static-top noborder nomargin ftransp hidden-xs hidden-sm">
#
#     <ul class="nav navbar-nav navbar-right">
# 	<!--
#       <li class="navbar-form">
#         <div class="row">
#           <div class="col-lg-12">
#             <div class="input-group" ng-controller="ctrlPesquisa">
#               <span class="input-group-btn" style="background-img: img/">
#                 <button class="btn btn-default" ng-click="Pesquisa(texto)">
#                   <img src="/img/icone_lupa.png" width="15" />
#                 </button>
#               </span>
#               <input type="text" class="form-control" placeholder="Pesquisar..." ng-model="texto"/>
#           </div>
#             <!-- /input-group
#           </div>
#           <!-- /.col-lg-6
#         </div>
#       </li> -->
# <!--
#       <li class="navbar-form dropdown">
#         <button class="btn btn-default dropdown-toggle" type="button" id="dropdownMenu1" data-toggle="dropdown" aria-haspopup="true" aria-expanded="False">
#                             Destaques
#                             <span class="caret"></span>
#                         </button>
#         <ul class="dropdown-menu">
#           <li>
#             <a class="" href="http://www.saopaulo.sp.gov.br/sis/noticias.asp">SP Notícias</a>
#           </li>
#           <li>
#             <a class="" href="http://www.poupatempo.sp.gov.br/">Poupatempo</a>
#           </li>
#           <li>
#             <a class="" href="http://www.acessasaopaulo.sp.gov.br/">Acessa São Paulo</a>
#           </li>
#           <li>
#             <a class="" href="http://www.e-negociospublicos.com.br/">Licitações</a>
#           </li>
#           <li role="separator" class="divider"></li>
#           <li class="dropdown-header">
#             Secretarias:<li />
#             <li>
#               <a class="" href="http://www.sap.sp.gov.br/">- Administração Penitenciária</a>
#             </li>
#             <li>
#               <a class="" href="http://www.agricultura.sp.gov.br/">- Agricultura e Abastecimento</a>
#             </li>
#             <li>
#               <a class="" href="http://www.desenvolvimentosocial.sp.gov.br/">- Assistência e Desenvolvimento Social</a>
#             </li>
#             <li>
#               <a class="" href="http://www.casacivil.sp.gov.br/">- Casa Civil</a>
#             </li>
#             <li>
#               <a class="" href="http://www.casamilitar.sp.gov.br/">- Casa Militar</a>
#             </li>
#             <li>
#               <a class="" href="http://www.comunicacao.sp.gov.br/">- Comunicação</a>
#             </li>
#             <li>
#               <a class="" href="http://www.cultura.sp.gov.br/">- Cultura</a>
#             </li>
#             <li>
#               <a class="" href="http://www.desenvolvimento.sp.gov.br/">- Desenvolvimento</a>
#             </li>
#             <li>
#               <a class="" href="http://www.pessoacomdeficiencia.sp.gov.br/">- Direitos da Pessoa com Deficiência</a>
#             </li>
#             <li>
#               <a class="" href="http://www.planejamento.sp.gov.br/">- Economia e Planejamento</a>
#             </li>
#             <li>
#               <a class="" href="http://www.educacao.sp.gov.br/">- Educação</a>
#             </li>
#             <li>
#               <a class="" href="http://www.emprego.sp.gov.br/">- Emprego e Relações do Trabalho</a>
#             </li>
#             <li>
#               <a class="" href="http://www.ensinosuperior.sp.gov.br/">- Ensino Superior</a>
#             </li>
#             <li>
#               <a class="" href="http://www.sejel.sp.gov.br/">- Esporte, Lazer e Turismo</a>
#             </li>
#             <li>
#               <a class="" href="http://www.fazenda.sp.gov.br/">- Fazenda</a>
#             </li>
#             <li>
#               <a class="" href="http://www.gestaopublica.sp.gov.br/">- Gestão Pública</a>
#             </li>
#             <li>
#               <a class="" href="http://www.habitacao.sp.gov.br/">- Habitação</a>
#             </li>
#             <li>
#               <a class="" href="http://www.justica.sp.gov.br/">- Justiça e Defesa da Cidadania</a>
#             </li>
#             <li>
#               <a class="" href="http://www.ambiente.sp.gov.br/">- Meio Ambiente</a>
#             </li>
#             <li>
#               <a class="" href="http://www.pge.sp.gov.br/">- Procuradoria Geral do Estado</a>
#             </li>
#             <li>
#               <a class="" href="http://www.relacoesinstitucionais.sp.gov.br/">- Relações Institucionais</a>
#             </li>
#             <li>
#               <a class="" href="http://www.energia.sp.gov.br/">- Saneamento e Energia</a>
#             </li>
#             <li>
#               <a class="" href="http://www.saude.sp.gov.br/">- Saúde</a>
#             </li>
#             <li>
#               <a class="" href="http://www.ssp.sp.gov.br/">- Segurança Pública</a>
#             </li>
#             <li>
#               <a class="" href="http://www.transportes.sp.gov.br/">- Transportes</a>
#             </li>
#             <li>
#               <a class="" href="http://www.stm.sp.gov.br/">- Transportes Metropolitanos</a>
#             </li>
#           </li>
#           </ul>
#       </li>
#
#       <li class="navbar-form norightPad">
#         <a href="https://www.facebook.com/segurancapublicasp" style="padding: 0px;">
#           <img src="/img/icone_face.png" alt="face" />
#         </a>
#       </li>
#
#       <li class="navbar-form leftPad">
#         <a href="https://twitter.com/SegurancaSP" style="padding: 0px;">
#           <img src="/img/icone_tw.png" alt="twitter" />
#         </a>
#       </li>
#
#       <li class="navbar-form norightPad">
#         <a href="http://www.policiamilitar.sp.gov.br/" style="padding: 0px;">
#           <img src="/img/incones_policias/policiamilitar.png" title="Policia Militar" class="not_tranform"/>
#         </a>
#       </li>
#       <li class="navbar-form norightPad">
#         <a href="http://www.policiacivil.sp.gov.br/" style="padding: 0px;">
#           <img src="/img/incones_policias/policiacivil.png" title="Polícia Civil" class="not_tranform"/>
#         </a>
#       </li>
#       <li class="navbar-form norightPad">
#         <a href="http://www.policiacientifica.sp.gov.br/" style="padding: 0px;">
#           <img src="/img/incones_policias/policiacientifica.png" title="Polícia Científica" class="not_tranform"/>
#         </a>
#       </li>
#     </ul>
#   </nav>-->
# </div><!-- MENU -->
# <div class="container">
# <nav class="navbar navbar-default hidden-xs hidden-sm hidden-md" style=" background-color: #ffffff!important;
#     border: 1px solid #595B5C!important;">
# <div class="container-fluid" style="background-color: #ffffff!important;">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <!--<a class="" href="/">
# 					<img alt="Endereço ssp.sp.gov.br" src="../img/bandeira-esq.png" class="not_tranform bandeira"/>
# 				</a>-->
# <a class="" href="/">
# <img alt="Endereço ssp.sp.gov.br" class="not_tranform bandeira" src="/img/bandeira-esq.png"/>
# </a>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
# <ul class="nav navbar-nav">
# <li>
# <a class="navitem" href="/Institucional/Default.aspx">INSTITUCIONAL</a>
# </li>
# <li>
# <a class="navitem" href="/noticia/UltimasNoticias.aspx">NOTÍCIAS</a>
# </li>
# <li>
# <a class="navitem" href="/acoes/">AÇÕES DE SEGURANÇA</a>
# </li>
# <li>
# <a class="navitem" href="/Estatistica/Default.aspx">ESTATÍSTICAS</a>
# </li>
# <li>
# <a class="navitem" href="http://www.ssp.sp.gov.br/nbo/">DELEGACIA ELETRÔNICA</a>
# </li>
# </ul>
# <div class="container navbar-search" id="menu">
# <div class="row">
# <button class="btn busca" data-target="#myModal" data-toggle="modal" type="button">
# <i class="glyphicon glyphicon-search" style="border-left: 1px solid;padding-left: 10px;"></i> Buscar</button>
# <div class="modal modal-busca fade" id="myModal" role="dialog">
# <div class="modal-dialog" style="margin: 85px 60%;">
# <div class="modal-content">
# <form class="" id="form-search" ng-controller="ctrlPesquisa">
# <div class="form-group col-md-8 col-lg-8">
# <input class="form-control inputbusca" ng-model="texto" placeholder="Digite sua pesquisa" type="search"/>
# </div>
# <div class="form-group col-md-4 col-lg-4">
# <button class="btn" ng-click="Pesquisa(texto)" style="background-color: transparent;">
# <i class="glyphicon glyphicon-search"></i>
# </button>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Fim do Busca -->
# </div>
# <!-- /.navbar-collapse -->
# </div>
# <!-- /.container-fluid -->
# </nav>
# </div>
# <div class="container theme-showcase .noPadding" role="main">
# <div class="col-lg-12">
# <div class="col-lg-9 col-md-12 col-sm-12 col-xs-12">
# <form action="./ViolenciaMulher.aspx" id="ctl00" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="C03832D5"/>
# <div class="container-fluid">
# <h2 style="color: #cc0000;"><b>Estatísticas</b></h2>
# <h3 style="color: #666;"><b>Violência Contra as Mulheres</b></h3>
# <div><b>(Lei n° 14.545 de 14 de setembro de 2011)</b></div>
# <br/>
# <div>
# <p>
# <b>NOTA TÉCNICA</b>
# </p>
# <ol style="font-size: 18px;">
# <li>
# 						Dados 2018 e 2019 - as naturezas Homicídio Doloso, Estupro e Estupro de Vulnerável (consumado e tentado) referem-se à quantidade de vítimas, havendo ou não
# 						violência doméstica associada no Boletim de Ocorrência.
# 					</li>
# <li>
# 						Considera-se nessa visualização Feminicídio (Inc VI, §2º do art. 121 do código penal) apenas os casos onde essa agravante foi incluída entre as naturezas
# 						no Boletim de Ocorrência.
# 					</li>
# <li>
# 						Fonte dados 2018 e 2019<br/>
# 						Homicídio Doloso, Estupro e Estupro de Vulnerável (consumado e tentado): R.D.O. (Registro Digital de Ocorrência);<br/>
# 						Demais dados: B.E.E. (Boletim Estatístico Eletrônico).
# 					</li>
# </ol>
# </div>
# <div id="conteudo_repPeriodo_divPeriodo_2">
# <div>
# <b>
# <span id="conteudo_repPeriodo_lblPeriodo_2">Ocorrências Registradas no mês: Novembro de 2021</span></b>
# </div>
# <div class="table-responsive" id="conteudo_repPeriodo_divGrid_2">
# <div>
# <table border="1" cellspacing="0" class="table table-striped table-hover table-condensed" id="conteudo_repPeriodo_grdOcorrencias_2" rules="all" style="margin-left: 0px;">
# <tr bgcolor="#337AB7">
# <th scope="col"><font color="White"> </font></th><th scope="col"><font color="White">Capital</font></th><th scope="col"><font color="White">Demacro</font></th><th scope="col"><font color="White">Interior</font></th><th scope="col"><font color="White">Total</font></th>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO (exclui FEMINICÍDIO)</td><td>4</td><td>1</td><td>7</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_0">12</span>
# </td>
# </tr><tr>
# <td>FEMINICÍDIO</td><td>1</td><td>0</td><td>8</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_1">9</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO - TOTAL</td><td>5</td><td>1</td><td>15</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_2">21</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO CULPOSO</td><td>0</td><td>0</td><td>0</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_3">0</span>
# </td>
# </tr><tr>
# <td>TENTATIVA DE HOMICÍDIO</td><td>5</td><td>10</td><td>25</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_4">40</span>
# </td>
# </tr><tr>
# <td>LESÃO CORPORAL DOLOSA</td><td>941</td><td>780</td><td>2831</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_5">4552</span>
# </td>
# </tr><tr>
# <td>MAUS TRATOS</td><td>5</td><td>2</td><td>29</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_6">36</span>
# </td>
# </tr><tr>
# <td>CALÚNIA - DIFAMAÇÃO - INJÚRIA</td><td>305</td><td>197</td><td>647</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_7">1149</span>
# </td>
# </tr><tr>
# <td>CONSTRANGIMENTO ILEGAL</td><td>0</td><td>1</td><td>8</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_8">9</span>
# </td>
# </tr><tr>
# <td>AMEAÇA</td><td>830</td><td>785</td><td>3496</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_9">5111</span>
# </td>
# </tr><tr>
# <td>INVASÃO DE DOMICÍLIO</td><td>3</td><td>13</td><td>27</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_10">43</span>
# </td>
# </tr><tr>
# <td>DANO</td><td>11</td><td>19</td><td>93</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_11">123</span>
# </td>
# </tr><tr>
# <td>ESTUPRO CONSUMADO</td><td>56</td><td>35</td><td>131</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_12">222</span>
# </td>
# </tr><tr>
# <td>ESTUPRO TENTADO</td><td>11</td><td>7</td><td>24</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_13">42</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL CONSUMADO</td><td>138</td><td>155</td><td>476</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_14">769</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL TENTADO</td><td>2</td><td>2</td><td>12</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_15">16</span>
# </td>
# </tr><tr>
# <td>OUTROS C/C/ DIGNIDADE SEXUAL</td><td>61</td><td>10</td><td>37</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_2_lblTotal_16">108</span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <b>Fonte: B.E.E. (Boletim Estatístico Eletrônico)</b>
# <br/>
# <br/>
# </div>
# <div id="conteudo_repPeriodo_divPeriodo_3">
# <div>
# <b>
# <span id="conteudo_repPeriodo_lblPeriodo_3">Ocorrências Registradas no mês: Outubro de 2021</span></b>
# </div>
# <div class="table-responsive" id="conteudo_repPeriodo_divGrid_3">
# <div>
# <table border="1" cellspacing="0" class="table table-striped table-hover table-condensed" id="conteudo_repPeriodo_grdOcorrencias_3" rules="all" style="margin-left: 0px;">
# <tr bgcolor="#337AB7">
# <th scope="col"><font color="White"> </font></th><th scope="col"><font color="White">Capital</font></th><th scope="col"><font color="White">Demacro</font></th><th scope="col"><font color="White">Interior</font></th><th scope="col"><font color="White">Total</font></th>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO (exclui FEMINICÍDIO)</td><td>2</td><td>3</td><td>9</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_0">14</span>
# </td>
# </tr><tr>
# <td>FEMINICÍDIO</td><td>3</td><td>1</td><td>5</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_1">9</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO - TOTAL</td><td>5</td><td>4</td><td>14</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_2">23</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO CULPOSO</td><td>0</td><td>0</td><td>0</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_3">0</span>
# </td>
# </tr><tr>
# <td>TENTATIVA DE HOMICÍDIO</td><td>1</td><td>5</td><td>19</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_4">25</span>
# </td>
# </tr><tr>
# <td>LESÃO CORPORAL DOLOSA</td><td>783</td><td>816</td><td>2682</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_5">4281</span>
# </td>
# </tr><tr>
# <td>MAUS TRATOS</td><td>2</td><td>1</td><td>22</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_6">25</span>
# </td>
# </tr><tr>
# <td>CALÚNIA - DIFAMAÇÃO - INJÚRIA</td><td>248</td><td>152</td><td>576</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_7">976</span>
# </td>
# </tr><tr>
# <td>CONSTRANGIMENTO ILEGAL</td><td>0</td><td>2</td><td>6</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_8">8</span>
# </td>
# </tr><tr>
# <td>AMEAÇA</td><td>836</td><td>671</td><td>3171</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_9">4678</span>
# </td>
# </tr><tr>
# <td>INVASÃO DE DOMICÍLIO</td><td>5</td><td>7</td><td>35</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_10">47</span>
# </td>
# </tr><tr>
# <td>DANO</td><td>12</td><td>9</td><td>81</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_11">102</span>
# </td>
# </tr><tr>
# <td>ESTUPRO CONSUMADO</td><td>57</td><td>26</td><td>116</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_12">199</span>
# </td>
# </tr><tr>
# <td>ESTUPRO TENTADO</td><td>9</td><td>8</td><td>27</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_13">44</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL CONSUMADO</td><td>141</td><td>153</td><td>377</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_14">671</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL TENTADO</td><td>7</td><td>6</td><td>11</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_15">24</span>
# </td>
# </tr><tr>
# <td>OUTROS C/C/ DIGNIDADE SEXUAL</td><td>25</td><td>13</td><td>31</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_3_lblTotal_16">69</span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <b>Fonte: B.E.E. (Boletim Estatístico Eletrônico)</b>
# <br/>
# <br/>
# </div>
# <div id="conteudo_repPeriodo_divPeriodo_4">
# <div>
# <b>
# <span id="conteudo_repPeriodo_lblPeriodo_4">Ocorrências Registradas no mês: Setembro de 2021</span></b>
# </div>
# <div class="table-responsive" id="conteudo_repPeriodo_divGrid_4">
# <div>
# <table border="1" cellspacing="0" class="table table-striped table-hover table-condensed" id="conteudo_repPeriodo_grdOcorrencias_4" rules="all" style="margin-left: 0px;">
# <tr bgcolor="#337AB7">
# <th scope="col"><font color="White"> </font></th><th scope="col"><font color="White">Capital</font></th><th scope="col"><font color="White">Demacro</font></th><th scope="col"><font color="White">Interior</font></th><th scope="col"><font color="White">Total</font></th>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO (exclui FEMINICÍDIO)</td><td>7</td><td>5</td><td>11</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_0">23</span>
# </td>
# </tr><tr>
# <td>FEMINICÍDIO</td><td>3</td><td>1</td><td>2</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_1">6</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO - TOTAL</td><td>10</td><td>6</td><td>13</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_2">29</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO CULPOSO</td><td>0</td><td>0</td><td>0</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_3">0</span>
# </td>
# </tr><tr>
# <td>TENTATIVA DE HOMICÍDIO</td><td>1</td><td>4</td><td>20</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_4">25</span>
# </td>
# </tr><tr>
# <td>LESÃO CORPORAL DOLOSA</td><td>904</td><td>872</td><td>2787</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_5">4563</span>
# </td>
# </tr><tr>
# <td>MAUS TRATOS</td><td>2</td><td>3</td><td>30</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_6">35</span>
# </td>
# </tr><tr>
# <td>CALÚNIA - DIFAMAÇÃO - INJÚRIA</td><td>259</td><td>187</td><td>638</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_7">1084</span>
# </td>
# </tr><tr>
# <td>CONSTRANGIMENTO ILEGAL</td><td>0</td><td>1</td><td>6</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_8">7</span>
# </td>
# </tr><tr>
# <td>AMEAÇA</td><td>855</td><td>744</td><td>3461</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_9">5060</span>
# </td>
# </tr><tr>
# <td>INVASÃO DE DOMICÍLIO</td><td>6</td><td>4</td><td>20</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_10">30</span>
# </td>
# </tr><tr>
# <td>DANO</td><td>8</td><td>18</td><td>73</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_11">99</span>
# </td>
# </tr><tr>
# <td>ESTUPRO CONSUMADO</td><td>49</td><td>35</td><td>99</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_12">183</span>
# </td>
# </tr><tr>
# <td>ESTUPRO TENTADO</td><td>12</td><td>13</td><td>26</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_13">51</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL CONSUMADO</td><td>138</td><td>130</td><td>425</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_14">693</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL TENTADO</td><td>12</td><td>4</td><td>12</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_15">28</span>
# </td>
# </tr><tr>
# <td>OUTROS C/C/ DIGNIDADE SEXUAL</td><td>17</td><td>18</td><td>28</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_4_lblTotal_16">63</span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <b>Fonte: B.E.E. (Boletim Estatístico Eletrônico)</b>
# <br/>
# <br/>
# </div>
# <div id="conteudo_repPeriodo_divPeriodo_5">
# <div>
# <b>
# <span id="conteudo_repPeriodo_lblPeriodo_5">Ocorrências Registradas no mês: Agosto de 2021</span></b>
# </div>
# <div class="table-responsive" id="conteudo_repPeriodo_divGrid_5">
# <div>
# <table border="1" cellspacing="0" class="table table-striped table-hover table-condensed" id="conteudo_repPeriodo_grdOcorrencias_5" rules="all" style="margin-left: 0px;">
# <tr bgcolor="#337AB7">
# <th scope="col"><font color="White"> </font></th><th scope="col"><font color="White">Capital</font></th><th scope="col"><font color="White">Demacro</font></th><th scope="col"><font color="White">Interior</font></th><th scope="col"><font color="White">Total</font></th>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO (exclui FEMINICÍDIO)</td><td>4</td><td>3</td><td>15</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_0">22</span>
# </td>
# </tr><tr>
# <td>FEMINICÍDIO</td><td>1</td><td>2</td><td>5</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_1">8</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO - TOTAL</td><td>5</td><td>5</td><td>20</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_2">30</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO CULPOSO</td><td>0</td><td>0</td><td>0</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_3">0</span>
# </td>
# </tr><tr>
# <td>TENTATIVA DE HOMICÍDIO</td><td>2</td><td>4</td><td>15</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_4">21</span>
# </td>
# </tr><tr>
# <td>LESÃO CORPORAL DOLOSA</td><td>979</td><td>878</td><td>2701</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_5">4558</span>
# </td>
# </tr><tr>
# <td>MAUS TRATOS</td><td>7</td><td>8</td><td>29</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_6">44</span>
# </td>
# </tr><tr>
# <td>CALÚNIA - DIFAMAÇÃO - INJÚRIA</td><td>358</td><td>192</td><td>639</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_7">1189</span>
# </td>
# </tr><tr>
# <td>CONSTRANGIMENTO ILEGAL</td><td>2</td><td>21</td><td>5</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_8">28</span>
# </td>
# </tr><tr>
# <td>AMEAÇA</td><td>1027</td><td>822</td><td>3535</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_9">5384</span>
# </td>
# </tr><tr>
# <td>INVASÃO DE DOMICÍLIO</td><td>10</td><td>6</td><td>34</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_10">50</span>
# </td>
# </tr><tr>
# <td>DANO</td><td>13</td><td>15</td><td>75</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_11">103</span>
# </td>
# </tr><tr>
# <td>ESTUPRO CONSUMADO</td><td>46</td><td>39</td><td>103</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_12">188</span>
# </td>
# </tr><tr>
# <td>ESTUPRO TENTADO</td><td>8</td><td>7</td><td>24</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_13">39</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL CONSUMADO</td><td>139</td><td>138</td><td>373</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_14">650</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL TENTADO</td><td>0</td><td>2</td><td>14</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_15">16</span>
# </td>
# </tr><tr>
# <td>OUTROS C/C/ DIGNIDADE SEXUAL</td><td>39</td><td>7</td><td>39</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_5_lblTotal_16">85</span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <b>Fonte: B.E.E. (Boletim Estatístico Eletrônico)</b>
# <br/>
# <br/>
# </div>
# <div id="conteudo_repPeriodo_divPeriodo_6">
# <div>
# <b>
# <span id="conteudo_repPeriodo_lblPeriodo_6">Ocorrências Registradas no mês: Julho de 2021</span></b>
# </div>
# <div class="table-responsive" id="conteudo_repPeriodo_divGrid_6">
# <div>
# <table border="1" cellspacing="0" class="table table-striped table-hover table-condensed" id="conteudo_repPeriodo_grdOcorrencias_6" rules="all" style="margin-left: 0px;">
# <tr bgcolor="#337AB7">
# <th scope="col"><font color="White"> </font></th><th scope="col"><font color="White">Capital</font></th><th scope="col"><font color="White">Demacro</font></th><th scope="col"><font color="White">Interior</font></th><th scope="col"><font color="White">Total</font></th>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO (exclui FEMINICÍDIO)</td><td>6</td><td>4</td><td>12</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_0">22</span>
# </td>
# </tr><tr>
# <td>FEMINICÍDIO</td><td>2</td><td>2</td><td>4</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_1">8</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO - TOTAL</td><td>8</td><td>6</td><td>16</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_2">30</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO CULPOSO</td><td>0</td><td>0</td><td>0</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_3">0</span>
# </td>
# </tr><tr>
# <td>TENTATIVA DE HOMICÍDIO</td><td>2</td><td>7</td><td>19</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_4">28</span>
# </td>
# </tr><tr>
# <td>LESÃO CORPORAL DOLOSA</td><td>889</td><td>733</td><td>2319</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_5">3941</span>
# </td>
# </tr><tr>
# <td>MAUS TRATOS</td><td>0</td><td>6</td><td>22</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_6">28</span>
# </td>
# </tr><tr>
# <td>CALÚNIA - DIFAMAÇÃO - INJÚRIA</td><td>215</td><td>143</td><td>543</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_7">901</span>
# </td>
# </tr><tr>
# <td>CONSTRANGIMENTO ILEGAL</td><td>96</td><td>2</td><td>10</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_8">108</span>
# </td>
# </tr><tr>
# <td>AMEAÇA</td><td>621</td><td>655</td><td>2979</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_9">4255</span>
# </td>
# </tr><tr>
# <td>INVASÃO DE DOMICÍLIO</td><td>5</td><td>12</td><td>24</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_10">41</span>
# </td>
# </tr><tr>
# <td>DANO</td><td>12</td><td>9</td><td>60</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_11">81</span>
# </td>
# </tr><tr>
# <td>ESTUPRO CONSUMADO</td><td>45</td><td>24</td><td>93</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_12">162</span>
# </td>
# </tr><tr>
# <td>ESTUPRO TENTADO</td><td>10</td><td>9</td><td>20</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_13">39</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL CONSUMADO</td><td>148</td><td>115</td><td>322</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_14">585</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL TENTADO</td><td>3</td><td>2</td><td>12</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_15">17</span>
# </td>
# </tr><tr>
# <td>OUTROS C/C/ DIGNIDADE SEXUAL</td><td>36</td><td>7</td><td>25</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_6_lblTotal_16">68</span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <b>Fonte: B.E.E. (Boletim Estatístico Eletrônico)</b>
# <br/>
# <br/>
# </div>
# <div id="conteudo_repPeriodo_divPeriodo_7">
# <div>
# <b>
# <span id="conteudo_repPeriodo_lblPeriodo_7">Ocorrências Registradas no mês: Junho de 2021</span></b>
# </div>
# <div class="table-responsive" id="conteudo_repPeriodo_divGrid_7">
# <div>
# <table border="1" cellspacing="0" class="table table-striped table-hover table-condensed" id="conteudo_repPeriodo_grdOcorrencias_7" rules="all" style="margin-left: 0px;">
# <tr bgcolor="#337AB7">
# <th scope="col"><font color="White"> </font></th><th scope="col"><font color="White">Capital</font></th><th scope="col"><font color="White">Demacro</font></th><th scope="col"><font color="White">Interior</font></th><th scope="col"><font color="White">Total</font></th>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO (exclui FEMINICÍDIO)</td><td>7</td><td>0</td><td>8</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_0">15</span>
# </td>
# </tr><tr>
# <td>FEMINICÍDIO</td><td>2</td><td>0</td><td>5</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_1">7</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO - TOTAL</td><td>9</td><td>0</td><td>13</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_2">22</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO CULPOSO</td><td>0</td><td>0</td><td>0</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_3">0</span>
# </td>
# </tr><tr>
# <td>TENTATIVA DE HOMICÍDIO</td><td>3</td><td>3</td><td>22</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_4">28</span>
# </td>
# </tr><tr>
# <td>LESÃO CORPORAL DOLOSA</td><td>707</td><td>760</td><td>2242</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_5">3709</span>
# </td>
# </tr><tr>
# <td>MAUS TRATOS</td><td>5</td><td>3</td><td>24</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_6">32</span>
# </td>
# </tr><tr>
# <td>CALÚNIA - DIFAMAÇÃO - INJÚRIA</td><td>248</td><td>110</td><td>464</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_7">822</span>
# </td>
# </tr><tr>
# <td>CONSTRANGIMENTO ILEGAL</td><td>1</td><td>1</td><td>13</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_8">15</span>
# </td>
# </tr><tr>
# <td>AMEAÇA</td><td>757</td><td>666</td><td>2842</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_9">4265</span>
# </td>
# </tr><tr>
# <td>INVASÃO DE DOMICÍLIO</td><td>8</td><td>7</td><td>18</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_10">33</span>
# </td>
# </tr><tr>
# <td>DANO</td><td>14</td><td>17</td><td>58</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_11">89</span>
# </td>
# </tr><tr>
# <td>ESTUPRO CONSUMADO</td><td>42</td><td>43</td><td>85</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_12">170</span>
# </td>
# </tr><tr>
# <td>ESTUPRO TENTADO</td><td>5</td><td>10</td><td>18</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_13">33</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL CONSUMADO</td><td>136</td><td>166</td><td>300</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_14">602</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL TENTADO</td><td>1</td><td>5</td><td>20</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_15">26</span>
# </td>
# </tr><tr>
# <td>OUTROS C/C/ DIGNIDADE SEXUAL</td><td>27</td><td>9</td><td>42</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_7_lblTotal_16">78</span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <b>Fonte: B.E.E. (Boletim Estatístico Eletrônico)</b>
# <br/>
# <br/>
# </div>
# <div id="conteudo_repPeriodo_divPeriodo_8">
# <div>
# <b>
# <span id="conteudo_repPeriodo_lblPeriodo_8">Ocorrências Registradas no mês: Maio de 2021</span></b>
# </div>
# <div class="table-responsive" id="conteudo_repPeriodo_divGrid_8">
# <div>
# <table border="1" cellspacing="0" class="table table-striped table-hover table-condensed" id="conteudo_repPeriodo_grdOcorrencias_8" rules="all" style="margin-left: 0px;">
# <tr bgcolor="#337AB7">
# <th scope="col"><font color="White"> </font></th><th scope="col"><font color="White">Capital</font></th><th scope="col"><font color="White">Demacro</font></th><th scope="col"><font color="White">Interior</font></th><th scope="col"><font color="White">Total</font></th>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO (exclui FEMINICÍDIO)</td><td>2</td><td>4</td><td>11</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_0">17</span>
# </td>
# </tr><tr>
# <td>FEMINICÍDIO</td><td>5</td><td>3</td><td>18</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_1">26</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO - TOTAL</td><td>7</td><td>7</td><td>29</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_2">43</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO CULPOSO</td><td>0</td><td>0</td><td>0</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_3">0</span>
# </td>
# </tr><tr>
# <td>TENTATIVA DE HOMICÍDIO</td><td>3</td><td>2</td><td>14</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_4">19</span>
# </td>
# </tr><tr>
# <td>LESÃO CORPORAL DOLOSA</td><td>695</td><td>761</td><td>2358</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_5">3814</span>
# </td>
# </tr><tr>
# <td>MAUS TRATOS</td><td>8</td><td>4</td><td>29</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_6">41</span>
# </td>
# </tr><tr>
# <td>CALÚNIA - DIFAMAÇÃO - INJÚRIA</td><td>236</td><td>158</td><td>495</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_7">889</span>
# </td>
# </tr><tr>
# <td>CONSTRANGIMENTO ILEGAL</td><td>1</td><td>0</td><td>5</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_8">6</span>
# </td>
# </tr><tr>
# <td>AMEAÇA</td><td>732</td><td>675</td><td>2991</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_9">4398</span>
# </td>
# </tr><tr>
# <td>INVASÃO DE DOMICÍLIO</td><td>2</td><td>11</td><td>28</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_10">41</span>
# </td>
# </tr><tr>
# <td>DANO</td><td>21</td><td>6</td><td>57</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_11">84</span>
# </td>
# </tr><tr>
# <td>ESTUPRO CONSUMADO</td><td>41</td><td>25</td><td>87</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_12">153</span>
# </td>
# </tr><tr>
# <td>ESTUPRO TENTADO</td><td>11</td><td>12</td><td>24</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_13">47</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL CONSUMADO</td><td>123</td><td>120</td><td>419</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_14">662</span>
# </td>
# </tr><tr>
# <td>ESTUPRO DE VULNERÁVEL TENTADO</td><td>0</td><td>4</td><td>9</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_15">13</span>
# </td>
# </tr><tr>
# <td>OUTROS C/C/ DIGNIDADE SEXUAL</td><td>15</td><td>12</td><td>34</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_8_lblTotal_16">61</span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <b>Fonte: B.E.E. (Boletim Estatístico Eletrônico)</b>
# <br/>
# <br/>
# </div>
# <div id="conteudo_repPeriodo_divPeriodo_9">
# <div>
# <b>
# <span id="conteudo_repPeriodo_lblPeriodo_9">Ocorrências Registradas no mês: Abril de 2021</span></b>
# </div>
# <div class="table-responsive" id="conteudo_repPeriodo_divGrid_9">
# <div>
# <table border="1" cellspacing="0" class="table table-striped table-hover table-condensed" id="conteudo_repPeriodo_grdOcorrencias_9" rules="all" style="margin-left: 0px;">
# <tr bgcolor="#337AB7">
# <th scope="col"><font color="White"> </font></th><th scope="col"><font color="White">Capital</font></th><th scope="col"><font color="White">Demacro</font></th><th scope="col"><font color="White">Interior</font></th><th scope="col"><font color="White">Total</font></th>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO (exclui FEMINICÍDIO)</td><td>10</td><td>8</td><td>7</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_0">25</span>
# </td>
# </tr><tr>
# <td>FEMINICÍDIO</td><td>3</td><td>1</td><td>6</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_1">10</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO DOLOSO - TOTAL</td><td>13</td><td>9</td><td>13</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_2">35</span>
# </td>
# </tr><tr>
# <td>HOMICÍDIO CULPOSO</td><td>0</td><td>0</td><td>0</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_3">0</span>
# </td>
# </tr><tr>
# <td>TENTATIVA DE HOMICÍDIO</td><td>11</td><td>7</td><td>18</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_4">36</span>
# </td>
# </tr><tr>
# <td>LESÃO CORPORAL DOLOSA</td><td>771</td><td>687</td><td>2398</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_5">3856</span>
# </td>
# </tr><tr>
# <td>MAUS TRATOS</td><td>7</td><td>5</td><td>45</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_6">57</span>
# </td>
# </tr><tr>
# <td>CALÚNIA - DIFAMAÇÃO - INJÚRIA</td><td>210</td><td>149</td><td>566</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_7">925</span>
# </td>
# </tr><tr>
# <td>CONSTRANGIMENTO ILEGAL</td><td>1</td><td>0</td><td>13</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_8">14</span>
# </td>
# </tr><tr>
# <td>AMEAÇA</td><td>768</td><td>619</td><td>3160</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_9">4547</span>
# </td>
# </tr><tr>
# <td>INVASÃO DE DOMICÍLIO</td><td>3</td><td>13</td><td>28</td><td>
# <span id="conteudo_repPeriodo_grdOcorrencias_9_lblTotal_10">44</span>
# </td>
# </tr><tr>
# <td>DANO</td><td>5</td><td>16</td><td>55</td><td>
# ...
# <span class="input-group-btn">
# <button class="btn input2btn" ng-click="Pesquisa(texto)" type="button">
# <img src="/img/icone_lupa.png">
# </img></button>
# </span>
# <input class="input1 form-control" ng-model="texto" placeholder="Buscar" style="color:#555;" type="text"/>
# </div>
# <img alt="face" class="icone_menu" src="/img/icone_face.png" style="padding-top: 8px; margin-left: 5px;"/>
# <img alt="twitter" class="icone_menu" src="/img/icone_tw.png" style="padding-top: 8px;"/>
# </div>
# </div>
# <div class="slide2">
# <!--<div class="row col-sm-3 col-md-3 hidden-sm hidden-xs" style="padding-bottom: 25px; padding-top: 25px;">-->
# <div class="sidebar-offcanvas" id="sidebar">
# <div class="list-group-mob">
# <a class="list-group-item-mob active" href="#">POLÍCIAS</a>
# <a class="list-group-item-mob" href="http://www.policiacivil.sp.gov.br/">
# <img class="icone_menu teste" src="/img/incones_policias/policiacivil.png" title="Polícia Civil"/>POLÍCIA CIVIL
#     </a>
# <a class="list-group-item-mob" href="http://www.policiacientifica.sp.gov.br/">
# <img class="icone_menu teste" src="/img/incones_policias/policiacientifica.png"/>POLÍCIA CIENTÍFICA
#     </a>
# <a class="list-group-item-mob" href="http://www.policiamilitar.sp.gov.br/">
# <img class="icone_menu teste" src="/img/incones_policias/policiamilitar.png"/>POLÍCIA MILITAR
#     </a>
# <a class="list-group-item-mob active" href="#">SSP-SP</a>
# <a class="list-group-item-mob" href="/Institucional/Default.aspx">
#       INSTITUCIONAL
#     </a>
# <a class="list-group-item-mob" href="/noticia/UltimasNoticias.aspx">
#       NOTÍCIAS
#     </a>
# <a class="list-group-item-mob" href="/acoes/">
#       AÇÕES DE SEGURANÇA
#     </a>
# <a class="list-group-item-mob" href="/Estatistica/Default.aspx">
#       ESTATÍSTICAS
#     </a>
# <a class="list-group-item-mob active" href="#">ESTATÍSTICA</a>
# <a class="list-group-item-mob" href="/Estatistica/Default.aspx">
# <img class="icone_menu" src="/img/Icones/Apresentacao.png"/>APRESENTAÇÃO
#     </a>
# <a class="list-group-item-mob" href="/Estatistica/Pesquisa.aspx">
# <img class="icone_menu" src="/img/Icones/dados_estatisticos.png"/>DADOS ESTATÍSTICOS
#     </a>
# <a class="list-group-item-mob" href="/Estatistica/Mapas.aspx">
# <img class="icone_menu" src="/img/Icones/dados_mapal.png"/>DADOS POR MAPA
#     </a>
# <a class="list-group-item-mob" href="/Estatistica/CorpoBombeiro.aspx">
# <img class="icone_menu" src="/img/Icones/estatistica_bombeiros.png"/>CORPO DE BOMBEIROS
#     </a>
# <a class="list-group-item-mob" href="/Estatistica/Trimestrais.aspx">
# <img class="icone_menu" src="/img/Icones/estatisticas_trimestrais.png"/>ESTATÍSTICAS TRIMESTRAIS
#     </a>
# <a class="list-group-item-mob" href="/Estatistica/ViolenciaMulher.aspx">
# <img class="icone_menu" src="/img/Icones/violencia_contra_mulheres.png"/>VIOLÊNCIA CONTRA AS MULHERES
#     </a>
# <!--<a href="/Estatistica/PerfilEstupro.aspx" class="list-group-item-mob">
#       <img src="/img/Icones/perfil_estupro.png" class="icone_menu" />PERFIL DE ESTUPRO
#     </a>-->
# <a class="list-group-item-mob" href="/Estatistica/PerfilHomicidio.aspx">
# <img class="icone_menu" src="/img/Icones/Perfil_Homicidio.png"/>PERFIL DE HOMICÍDIO
#     </a>
# <a class="list-group-item-mob" href="/Estatistica/PerfilRoubo.aspx">
# <img class="icone_menu" src="/img/Icones/perfil_roubo.png"/>PERFIL DE ROUBO
#     </a>
# <a class="list-group-item-mob" href="/Estatistica/Estudos.aspx">
# <img class="icone_menu" src="/img/Icones/estudos.png"/>RELATÓRIOS E ESTUDOS
#     </a>
# <a class="list-group-item-mob" href="http://www.ssp.sp.gov.br/transparenciassp/Default.aspx">
# <img class="icone_menu" src="/img/Icones/transparencia_ssp.png"/>TRANSPARÊNCIA SSP
#     </a>
# <a class="list-group-item-mob active" href="https://delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/home">DELEGACIA ELETRÔNICA</a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia/roubo-ou-furto-de-veiculos/ssp-roubo-ou-furto-de-veiculos.xhtml">
# <img class="icone_menu" src="/img/icones_de/ico_furtoroubo_veiculo.png"/>ROUBO OU FURTO DE VEÍCULO
#     </a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia">
# <img class="icone_menu" src="/img/icones_de/ico_furto_dcobj.png"/>FURTO DE DOCUMENTOS, CELULARES E/OU OBJETOS
# 	</a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia">
# <img class="icone_menu" src="/img/icones_de/ico_perda_dcobj.png"/>PERDA DE DOCUMENTOS, CELULARES E/OU OBJETOS
# 	</a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia/roubo-de-documentos-e-ou-objetos/ssp-roubo-de-documentos-e-ou-objetos.xhtml">
# <img class="icone_menu" src="/img/icones_de/ico_roubo_docobj.png"/>ROUBO DE DOCUMENTOS E/OU CELULARES
#     </a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia/furto-de-fios-e-cabos/triagem-documentos-da-empresa">
# <img class="icone_menu" src="/img/icones_de/ico_furto_fios.png"/>FURTO DE FIOS E/OU CABOS EM VIAS PÚBLICAS
# 	</a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia/injuria-calunia-ou-difamacao/ssp-injuria-calunia-ou-difamacao.xhtml">
# <img class="icone_menu" src="/img/icones_de/ico_crimeshonra.png"/>INJÚRIA, CALÚNIA OU DIFAMAÇÃO
#     </a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia/acidente-de-transito-sem-vitimas/ssp-acidente-de-transito-sem-vitimas.xhtml">
# <img class="icone_menu" src="/img/icones_de/ico_acidentetransito.png"/>ACIDENTE DE TRÂNSITO SEM VÍTIMAS
#     </a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia/desaparecimento-de-pessoas/ssp-desaparecimento-de-pessoas.xhtml">
# <img class="icone_menu" src="/img/icones_de/ico_desaparecimento.png"/>DESAPARECIMENTO DE PESSOAS
#     </a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia/encontro-de-pessoas/ssp-encontro-de-pessoas.xhtml">
# <img class="icone_menu" src="/img/icones_de/ico_encontro.png"/>ENCONTRO DE PESSOAS
#     </a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia/violencia-domestica/triagem-de-vitima">
# <img class="icone_menu" src="/img/icones_de/ico_violencia_dom.png"/>VIOLÊNCIA DOMÉSTICA
# 	</a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/comunicar-ocorrencia/outras-ocorrencias/gravidade-da-ocorrencia">
# <img class="icone_menu" src="/img/icones_de/ico_outras.png"/>OUTRAS OCORRÊNCIAS
# 	</a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/complementar-boletim/complementar-boletim">
# <img class="icone_menu" src="/img/icones_de/ico_complementar.png"/>COMPLEMENTAR BOLETIM
#     </a>
# <a class="list-group-item-mob" href="https://www.delegaciaeletronica.policiacivil.sp.gov.br/ssp-de-cidadao/pages/acompanhar-andamento">
# <img class="icone_menu" src="/img/icones_de/ico_acompanhar.png"/>ACOMPANHAR BOLETIM
#     </a>
# <a class="list-group-item-mob" href="http://www.ssp.sp.gov.br/depa" target="_top">
# <img class="icone_menu" src="/img/icones_de/ico_depa.png"/>DEPA - PROTEÇÃO ANIMAL
#     </a>
# <a class="list-group-item-mob active" href="/servicos/denuncias/">DENÚNCIAS</a>
# <a class="list-group-item-mob" href="https://www.webdenuncia.org.br/">
# <img class="icone_menu" src="/img/icones_denuncia/disquedenuncia_181_azul.png"/>DISQUE DENÚNCIA 181
#     </a>
# <a class="list-group-item-mob" href="https://www.webdenuncia.org.br/">
# <img class="icone_menu" src="/img/icones_denuncia/webdenuncia_azul.png"/>WEB DENÚNCIA
#     </a>
# <a class="list-group-item-mob" href="/recompensas/Recompensas.aspx">
# <img class="icone_menu" src="/img/icones_denuncia/recompensa_azul.png"/>PROGRAMA DE RECOMPENSA
#     </a>
# <a class="list-group-item-mob active" href="#">SERVIÇOS</a>
# <a class="list-group-item-mob" href="/servicos/atestado.aspx">
# <img class="icone_menu" src="/img/icones_servicos/atestadodeantecedentes_azul.png"/>ATESTADO DE ANTECEDENTES
#     </a>
# <a class="list-group-item-mob" href="http://bopm.policiamilitar.sp.gov.br/">
# <img class="icone_menu" src="/img/icones_servicos/BOeletronico_azul.png"/>BOLETIM DE OCORRÊNCIA ELETRÔNICO
#     </a>
# <a class="list-group-item-mob" href="/servicos/manual-seguranca.aspx">
# <img class="icone_menu" src="/img/icones_servicos/concursos_azul.png"/>MANUAL DE SEGURANÇA
#     </a>
# <a class="list-group-item-mob" href="/servicos/190.aspx">
# <img class="icone_menu" src="/img/icones_servicos/telefonepolicia_azul.png"/>TELEFONES DA POLICIA
#     </a>
# <a class="list-group-item-mob" href="https://www.poupatempo.sp.gov.br/">
# <img class="icone_menu" src="/img/icones_servicos/2viarg_azul.png"/>1ª OU 2ª VIA DE RG
#     </a>
# <a class="list-group-item-mob" href="/servicos/pessoas_desaparecidas.aspx">
# <img class="icone_menu" src="/img/icones_servicos/desaparecido_azul.png"/>PESSOAS DESAPARECIDAS
#     </a>
# <a class="list-group-item-mob" href="http://www.policiacivil.sp.gov.br/portal/faces/pages_servicos/procuradosJustica">
# <img class="icone_menu" src="/img/icones/Procurado.png"/>PROCURADOS PELA JUSTIÇA
#     </a>
# <a class="list-group-item-mob" href="/servicos/mapaTelefones.aspx">
# <img class="icone_menu" src="/img/icones_servicos/telefonepolicia_azul.png"/>TELEFONES DA POLICIA
#     </a>
# <a class="list-group-item-mob" href="/servicos/Aplicativos.aspx">
# <img class="icone_menu" src="/img/icones_servicos/aplicativos_azul.png"/>APLICATIVOS
#     </a>
# <a class="list-group-item-mob" href="/servicos/mapaTelefones.aspx">
# <img class="icone_menu" src="/img/icones_servicos/unid_pol.png"/>UNIDADES POLICIAIS
#     </a>
# <a class="list-group-item-mob" href="/servicos/Celulares.aspx">
# <img class="icone_menu" src="/img/icones_servicos/Celular.png"/>CONSULTAR CELULARES
#     </a>
# <a class="list-group-item" href="http://www.ssp.sp.gov.br/consultabicicleta">
# <img class="icone_menu" src="/img/icones_servicos/Bicicleta.png"/>CONSULTAR BICICLETA
#     </a>
# <a class="list-group-item-mob" href="/servicos/CruzAzul.aspx">
# <img class="icone_menu" src="/img/icones_servicos/hosp_cruzazul.png"/>CRUZ AZUL
#     </a>
# <a class="list-group-item-mob active" href="#">PORTAIS</a>
# <a class="list-group-item-mob" href="http://www.ssp.sp.gov.br/conseg/">
# <img class="icone_menu" src="/img/icones_portais/conseg.png"/>CONSEG
#     </a>
# <a class="list-group-item-mob" href="http://www.ouvidoria-policia.sp.gov.br/">
# <img class="icone_menu" src="/img/icones_portais/ouvidoria.png"/>OUVIDORIA
#     </a>
# <a class="list-group-item-mob" href="http://www.ssp.sp.gov.br/transparenciassp/">
# <img class="icone_menu" src="/img/icones_portais/ssp.png"/>PORTAL DA TRANSPARENCIA
#     </a>
# <a class="list-group-item-mob" href="http://www.cidadao.sp.gov.br/">
# <img class="icone_menu" src="/img/icones_portais/cidadao.png"/>PORTAL CIDADÃO
#     </a>
# <a class="list-group-item-mob" href="http://portal.convenios.gov.br/">
# <img class="icone_menu" src="/img/icones_portais/siconv.png"/>SICONV
#     </a>
# <a class="list-group-item-mob" href="http://www.sic.sp.gov.br/">
# <img class="icone_menu" src="/img/icones_portais/sic_ico.png"/>SIC.<b>SP</b>
# </a>
# <a class="list-group-item-mob" href="http://www.ssp.sp.gov.br/leiloessp/">
# <img class="icone_menu" src="/img/icones_portais/leiloes.jpg"/>LEILÕES
# 	</a>
# <a class="list-group-item-mob" href="http://www.ssp.sp.gov.br/DoacoesSSP/">
# <img class="icone_menu" src="/img/icones_portais/handshake.png"/>DOAÇÕES AO PODER PÚBLICO
# 	</a>
# </div>
# </div>
# <!--</div>-->
# </div>
# </ng-slide-push-menu>
# <script type="text/javascript">
# 		function validaModal() {
# 			var iframe = document.getElementById('ifrmEmail');
# 			if (iframe.contentDocument)
# 				iFrameBody = iframe.contentDocument.getElementsByName('btnEnviar');
# 			$(iFrameBody).trigger('click');
# 		}
#
# 		function validaModalInfo() {
# 			var iframe = document.getElementById('ifrmInfo');
# 			if (iframe.contentDocument)
# 				iFrameBody = iframe.contentDocument.getElementsByName('btnCadastrar');
# 			$(iFrameBody).trigger('click');
# 		}
# 	</script>
# <div aria-labelledby="myModalLabel" class="modal fade" id="myModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# <h4 class="modal-title" id="myModalLabel">Secretaria de Estado da Segurança Pública</h4>
# </div>
# <div class="modal-body">
# <p class="nomargin topPad botPad">Rua Libero Badaró, 39, Centro, SP - CEP: 01009-000</p>
# <p class="nomargin topPad botPad">Telefones: (11) 3291-6500</p>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default btn-primary" data-dismiss="modal" type="button">FECHAR</button>
# </div>
# </div>
# </div>
# </div>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="modalEmail" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content centered">
# <div class="modal-header alert-info">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true" style="color:white;">×</span>
# </button>
# <h4 class="modal-title" id="modalTitulo">Secretaria de Estado da Segurança Pública</h4>
# </div>
# <div class="modal-custom-body">
# <div id="ContentIframe">
# <iframe class="col-xs-12 col-lg-12 col-md-12 col-sm-12" frameborder="0" height="565" id="ifrmEmail" src=""></iframe>
# </div>
# </div>
# <div class="modal-footer alert-info">
# <button class="btn btn-primary" onclick="validaModal();" type="button">Enviar</button>
# <button class="btn btn-default" data-dismiss="modal" id="btnCancelarInfo" type="button">Fechar</button>
# </div>
# </div>
# </div>
# </div>
# <div aria-labelledby="myModalLabel" class="modal fade" id="modalInfo" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content centered">
# <div class="modal-header alert-info">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true" style="color:white;">×</span>
# </button>
# <h4 class="modal-title" id="modalTituloInfo">Secretaria de Estado da Segurança Pública</h4>
# </div>
# <div class="modal-custom-body">
# <div id="ContentIframeInfo">
# <iframe class="col-xs-12 col-lg-12 col-md-12 col-sm-12" frameborder="0" height="370" id="ifrmInfo"></iframe>
# </div>
# </div>
# <div class="modal-footer alert-info">
# <button class="btn btn-primary" onclick="validaModalInfo();" type="button">Cadastrar</button>
# <button class="btn btn-default" data-dismiss="modal" id="btnCancelar" type="button">Fechar</button>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 		(function(i, s, o, g, r, a, m) {
# 			i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function() {
# 				(i[r].q = i[r].q || []).push(arguments)
# 			}, i[r].l = 1 * new Date(); a = s.createElement(o),
# 			m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# 			})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
# 			ga('create', 'UA-45808762-1', 'sp.gov.br');
# 			ga('send', 'pageview');
# 	</script>
# <script type="text/javascript">
# 	function resizeIframe(obj){
# 		 obj.style.height = 0;
# 		 obj.style.height = obj.contentWindow.document.body.scrollHeight + 'px';
# 	}
# 	</script>
# <script>(function(d, s, id) {
# 	  var js, fjs = d.getElementsByTagName(s)[0];
# 	  if (d.getElementById(id)) return;
# 	  js = d.createElement(s); js.id = id;
# 	  js.src = "//connect.facebook.net/pt_BR/sdk.js#xfbml=1&version=v2.8&appId=301523910212276";
# 	  fjs.parentNode.insertBefore(js, fjs);
# 	}(document, 'script', 'facebook-jssdk'));
# 	</script>
# </body>
# </html>

# %%
# Acessando titulo
print( Coleta.title )

# Acessar nome dentro das Tags
print( Coleta.title.string )

# Extrair o nome da TAG
print( Coleta.title.name )
# Out:
# <title>
# 	SSP
# </title>
#
# 	SSP
#
# title

# %%
# Coletando a tag
print( Coleta.a , '\n')

# Coletando o link dentro da Tag
print( Coleta.a.get('href') )
# Out:
# <a href="http://www.saopaulo.sp.gov.br/" target="_blank">Portal do Governo</a>
#
# http://www.saopaulo.sp.gov.br/

# %%
# Loop para extrair os links
for Loop in Coleta.find_all('a'):

  # Pegando o link da Tag
  link = Loop.get('href')

  # Verificando se existe um link externo
  if 'http://' in str(link) :
    print(link)

  else:
    pass
# Out:
# http://www.saopaulo.sp.gov.br/
# http://www.policiamilitar.sp.gov.br/
# http://www.policiacivil.sp.gov.br/
# http://www.policiacientifica.sp.gov.br/
# http://www.saopaulo.sp.gov.br/sis/noticias.asp
# http://www.poupatempo.sp.gov.br/
# http://www.acessasaopaulo.sp.gov.br/
# http://www.e-negociospublicos.com.br/
# http://www.sap.sp.gov.br/
# http://www.agricultura.sp.gov.br/
# http://www.desenvolvimentosocial.sp.gov.br/
# http://www.casacivil.sp.gov.br/
# http://www.casamilitar.sp.gov.br/
# http://www.comunicacao.sp.gov.br/
# http://www.cultura.sp.gov.br/
# http://www.desenvolvimento.sp.gov.br/
# http://www.pessoacomdeficiencia.sp.gov.br/
# http://www.planejamento.sp.gov.br/
# http://www.educacao.sp.gov.br/
# http://www.emprego.sp.gov.br/
# http://www.ensinosuperior.sp.gov.br/
# http://www.sejel.sp.gov.br/
# http://www.fazenda.sp.gov.br/
# http://www.gestaopublica.sp.gov.br/
# http://www.habitacao.sp.gov.br/
# http://www.justica.sp.gov.br/
# http://www.ambiente.sp.gov.br/
# http://www.pge.sp.gov.br/
# http://www.relacoesinstitucionais.sp.gov.br/
# http://www.energia.sp.gov.br/
# http://www.saude.sp.gov.br/
# http://www.ssp.sp.gov.br/
# http://www.transportes.sp.gov.br/
# http://www.stm.sp.gov.br/
# http://www.ssp.sp.gov.br/nbo/
# http://www.ssp.sp.gov.br/transparenciassp/Default.aspx
# http://www.ssp.sp.gov.br/depa
# http://bopm.policiamilitar.sp.gov.br/
# http://www.policiacivil.sp.gov.br/portal/faces/pages_servicos/procuradosJustica
# http://www.ssp.sp.gov.br/consultabicicleta
# http://www.ssp.sp.gov.br/conseg/
# http://www.ouvidoria-policia.sp.gov.br/
# http://www.ssp.sp.gov.br/transparenciassp/
# http://www.cidadao.sp.gov.br/
# http://portal.convenios.gov.br/
# http://www.sic.sp.gov.br/
# http://www.ssp.sp.gov.br/leiloessp/
# http://www.ssp.sp.gov.br/DoacoesSSP/
# http://www.saopaulo.sp.gov.br/
# http://www.investe.sp.gov.br/
# http://www.cidadao.sp.gov.br/
# http://www.saopaulo.sp.gov.br/
# http://www.policiacivil.sp.gov.br/
# http://www.policiacientifica.sp.gov.br/
# http://www.policiamilitar.sp.gov.br/
# http://www.ssp.sp.gov.br/transparenciassp/Default.aspx
# http://www.ssp.sp.gov.br/depa
# http://bopm.policiamilitar.sp.gov.br/
# http://www.policiacivil.sp.gov.br/portal/faces/pages_servicos/procuradosJustica
# http://www.ssp.sp.gov.br/consultabicicleta
# http://www.ssp.sp.gov.br/conseg/
# http://www.ouvidoria-policia.sp.gov.br/
# http://www.ssp.sp.gov.br/transparenciassp/
# http://www.cidadao.sp.gov.br/
# http://portal.convenios.gov.br/
# http://www.sic.sp.gov.br/
# http://www.ssp.sp.gov.br/leiloessp/
# http://www.ssp.sp.gov.br/DoacoesSSP/

# %%
Coleta.find( id='conteudo_repPeriodo_lblPeriodo_2' ).get_text().split()[-3:]
# Out:
# ['Novembro', 'de', '2021']

# %%
# Buscar todas as tabelas
Tabelas = Coleta.find_all('table', attrs={'class':'table table-striped table-hover table-condensed'} )

print( 'Total de Tabelas Localizadas:', len(Tabelas) )
# Out:
# Total de Tabelas Localizadas: 123

# %%
# Listas para salvar os dados
Rotulos = []
Dados = []
Periodos = []

# Função para criar uma Data
import datetime
from dateutil.relativedelta import relativedelta

# Ultima data publicada pelo estado
Registro_Inicial = datetime.datetime(2021, 11, 1)

# Variavel de Apoio
Loop = 0

# Loop
for Consulta in Tabelas:

  # Linhas
  Linha = Consulta.find_all('tr')[2]

  # Rotulo da Tabela
  Rotulo = Linha.find_all('td')[0].text

  # Valor da tabela
  Informacao = Linha.find_all('span')[0].text

  # Periodo do loop
  Data = Registro_Inicial - relativedelta( months=Loop )

  # Condição para verificar se é Feminicído
  if Rotulo == 'FEMINICÍDIO':
    Dados.append( Informacao )
    Rotulos.append( Rotulo )
    Periodos.append( Data )

  # Caso contrario, passa
  else:
    pass

  Loop += 1

# %%
# Organizar essas info Dicionairo

Dicionario = {
    'Rotulo' : Rotulos,
    'Quantidade' : Dados,
    'Periodo' : Periodos
}

# Criar o DataFame
Base_Dados = pd.DataFrame( Dicionario )

# %%
Base_Dados.to_excel('Base_Dados - Feminicidio.xlsx', index=False )

# %%
Base_Dados
# Out:
#          Rotulo Quantidade    Periodo
# 0   FEMINICÍDIO          9 2021-11-01
# 1   FEMINICÍDIO          9 2021-10-01
# 2   FEMINICÍDIO          6 2021-09-01
# 3   FEMINICÍDIO          8 2021-08-01
# 4   FEMINICÍDIO          8 2021-07-01
# 5   FEMINICÍDIO          7 2021-06-01
# 6   FEMINICÍDIO         26 2021-05-01
# 7   FEMINICÍDIO         10 2021-04-01
# 8   FEMINICÍDIO         21 2021-03-01
# 9   FEMINICÍDIO         11 2021-02-01
# 10  FEMINICÍDIO         11 2021-01-01
# 11  FEMINICÍDIO         19 2020-12-01
# 12  FEMINICÍDIO         20 2020-11-01
# 13  FEMINICÍDIO         14 2020-10-01
# 14  FEMINICÍDIO         17 2020-09-01
# 15  FEMINICÍDIO          8 2020-08-01
# 16  FEMINICÍDIO         13 2020-07-01
# 17  FEMINICÍDIO          8 2020-06-01
# 18  FEMINICÍDIO          9 2020-05-01
# 19  FEMINICÍDIO         21 2020-04-01
# 20  FEMINICÍDIO         20 2020-03-01
# 21  FEMINICÍDIO         18 2020-02-01
# 22  FEMINICÍDIO         12 2020-01-01
# 23  FEMINICÍDIO         27 2019-12-01
# 24  FEMINICÍDIO         17 2019-11-01
# 25  FEMINICÍDIO         18 2019-10-01
# 26  FEMINICÍDIO         19 2019-09-01
# 27  FEMINICÍDIO         13 2019-08-01
# 28  FEMINICÍDIO          5 2019-07-01
# 29  FEMINICÍDIO         11 2019-06-01
# 30  FEMINICÍDIO         19 2019-05-01
# 31  FEMINICÍDIO         16 2019-04-01
# 32  FEMINICÍDIO         13 2019-03-01
# 33  FEMINICÍDIO         12 2019-02-01
# 34  FEMINICÍDIO         14 2019-01-01
# 35  FEMINICÍDIO         15 2018-12-01
# 36  FEMINICÍDIO          9 2018-11-01
# 37  FEMINICÍDIO         17 2018-10-01
# 38  FEMINICÍDIO         11 2018-09-01
# 39  FEMINICÍDIO         11 2018-08-01
# 40  FEMINICÍDIO         16 2018-07-01
# 41  FEMINICÍDIO          6 2018-06-01
# 42  FEMINICÍDIO         16 2018-05-01
# 43  FEMINICÍDIO         14 2018-04-01
# 44  FEMINICÍDIO          8 2018-03-01
# 45  FEMINICÍDIO          8 2018-02-01
# 46  FEMINICÍDIO          5 2018-01-01
